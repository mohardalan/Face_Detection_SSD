# %% [markdown]
# ## Face Detection Model Using CNNs

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import cv2
import numpy as np
from PIL import Image
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Conv2D, Flatten, Dense, MaxPooling2D
from tensorflow.keras.layers import BatchNormalization, Dropout, Add, Activation
from sklearn.metrics import confusion_matrix, f1_score, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Define the new directory path
new_directory = '/content/drive/MyDrive/Colab Notebooks'

# Change the current working directory to the new one
os.chdir(new_directory)

# Verify the change by printing the current working directory
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /content/drive/MyDrive/Colab Notebooks

# %% [markdown]
# ### Data Preprocessing

# %%
# Set the directory where the data is stored
data_dir = "Data/lfw_funneled"

# Define the labels
labels= os.listdir(data_dir)

# %%
def rand_label_Func(labels, data_dir):
    rand_label= np.random.choice(a=labels)
    path = os.path.join(data_dir, rand_label)

    if len(os.listdir(path)) == 1:
        img= os.listdir(path)[0]
        rand_img= os.path.join(path, img)
    else:
        img= np.random.choice(a= os.listdir(path))
        rand_img= os.path.join(path, img)
    return str(rand_img)

# %%
Images_list = []
Target_list = []

for label in labels[:600]:
    path = os.path.join(data_dir, label)
    img_set= set(os.listdir(path))

    for img in os.listdir(path):
        rand_label= rand_label_Func(labels, data_dir)
        label_list= [os.path.join(path, img), rand_label]
        Images_list.append(label_list)
        Target_list.append(0)

        img_set.remove(img)
        for next_img in img_set:
            label_list= [os.path.join(path, img), os.path.join(path, next_img)]
            Images_list.append(label_list)
            Target_list.append(1)

            rand_label= rand_label_Func(labels, data_dir)
            label_list= [os.path.join(path, img), rand_label]
            Images_list.append(label_list)
            Target_list.append(0)

Images_list= np.array(Images_list)
Target_list= np.array(Target_list)
print('Dataset Shape: ', Images_list.shape)
print('The ration of classes: ', sum(Target_list)/len(Target_list))
# Out:
# Dataset Shape:  (5861, 2)
# The ration of classes:  0.4047090940112609

# %%
# Definitions
img_width, img_height = 128, 128
batch_size = 32
No_epochs= 40

# %%
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(Images_list, Target_list, test_size=0.1, random_state=42, stratify=Target_list)

# Split the data into training and dev sets
X_train, X_dev, y_train, y_dev = train_test_split(X_train, y_train, test_size=0.1, random_state=42, stratify=y_train)

print('Training set size: ', len(X_train))
print('Test set size: ', len(X_test))
print('Dev set size: ', len(X_dev))
# Out:
# Training set size:  4746
# Test set size:  587
# Dev set size:  528

# %% [markdown]
# ### Sample images

# %%
# Plot the images
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i + 1)
    image = Image.open(np.random.choice(X_train[:,0]))
    plt.imshow(image)
    plt.axis('off')
plt.show()

# %%
# Function to load and preprocess images
def load_images(X, img_width, img_height):
    images = []
    for image_path in X:
        image = cv2.imread(image_path)
        image = cv2.resize(image, (img_width, img_height)) 
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert to RGB
        image = image / 255.0  # Normalize pixel values
        images.append(image)

    images = np.array(images)
    return images

# Load and preprocess images
X_train= np.array([load_images(pair, img_width, img_height) for pair in X_train])

X_test = np.array([load_images(pair, img_width, img_height) for pair in X_test])

X_dev = np.array([load_images(pair, img_width, img_height) for pair in X_dev])

# %%
# Check if GPU is available
if tf.config.list_physical_devices('GPU'):
    print('GPU is available')
    # Set device for TensorFlow operations
    tf.config.set_visible_devices(tf.config.list_physical_devices('GPU')[0], 'GPU')
else:
    print('GPU is not available')
# Out:
# GPU is available

# %% [markdown]
# ### Defining the model

# %%
# Base convolutional model
image_input1 = Input(shape= (img_width, img_height, 3))
image_input2 = Input(shape= (img_width, img_height, 3))

# %%
# Option-1
#Base_model = keras.applications.ResNet50(include_top=False, weights='imagenet', input_shape= (img_width, img_height, 3))
# Option-2
Base_model = keras.applications.VGG19(include_top=False, weights='imagenet', input_shape= (img_width, img_height, 3))

print(f'Number of Layers in Base Model: {len(Base_model.layers)}')

for layer in Base_model.layers[:18]:
    layer.trainable = False

Base_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 0s 0us/step
# Number of Layers in Base Model: 22
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 128, 128, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 128, 128, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 128, 128, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 64, 64, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 64, 64, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 64, 64, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 32, 32, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 32, 32, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 32, 32, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 32, 32, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 32, 32, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 16, 16, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 16, 16, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block5_conv4 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
# =================================================================
# Total params: 20024384 (76.39 MB)
# Trainable params: 7079424 (27.01 MB)
# Non-trainable params: 12944960 (49.38 MB)
# _________________________________________________________________

# %%
# Flatten and dense layers
Flatten1 = Flatten()

# %%
def Generator_model(image_input):
    #x0= data_augmentation(image_input)
    x0= image_input

    # Base_model layer
    x1= Base_model(x0)

    # Flatten and dense layers
    x2= Flatten1(x1)

    return x2

# %%
x1= Generator_model(image_input1)
x2= Generator_model(image_input2)

# %%
# Merge branches
Dense1 = Dense(128, activation='relu')
Dropout1 = Dropout(0.2)
Dense2 = Dense(1, activation='sigmoid')

# %%
def discriminator_model(x1, x2):
    X1= Dense1(x1 - x2)
    X2= Dropout1(X1)
    X3= Dense2(X2)
    return X3

# %%
output= discriminator_model(x1, x2)

# %%
# Create model
model = Model(inputs=[image_input1, image_input2], outputs=output)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 3)]        0         []
#
#  input_2 (InputLayer)        [(None, 128, 128, 3)]        0         []
#
#  vgg19 (Functional)          (None, 4, 4, 512)            2002438   ['input_1[0][0]',
#                                                           4          'input_2[0][0]']
#
#  flatten (Flatten)           (None, 8192)                 0         ['vgg19[0][0]',
#                                                                      'vgg19[1][0]']
#
#  tf.math.subtract (TFOpLamb  (None, 8192)                 0         ['flatten[0][0]',
#  da)                                                                 'flatten[1][0]']
#
#  dense (Dense)               (None, 128)                  1048704   ['tf.math.subtract[0][0]']
#
#  dropout (Dropout)           (None, 128)                  0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 1)                    129       ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 21073217 (80.39 MB)
# Trainable params: 8128257 (31.01 MB)
# Non-trainable params: 12944960 (49.38 MB)
# __________________________________________________________________________________________________

# %%
# Compile model
model.compile(loss='binary_crossentropy', optimizer=Adam(), metrics=['accuracy'])

# %%
# Train model
with tf.device('/GPU:0'):
  history = model.fit([X_train[:,0], X_train[:,1]], y_train, epochs= No_epochs, batch_size= batch_size, validation_data=([X_dev[:,0], X_dev[:,1]], y_dev))
# Out:
# Epoch 1/40
# 149/149 [==============================] - 36s 174ms/step - loss: 0.6712 - accuracy: 0.6068 - val_loss: 0.6029 - val_accuracy: 0.6534
# Epoch 2/40
# 149/149 [==============================] - 19s 128ms/step - loss: 0.5701 - accuracy: 0.7059 - val_loss: 0.5172 - val_accuracy: 0.7405
# Epoch 3/40
# 149/149 [==============================] - 20s 132ms/step - loss: 0.4264 - accuracy: 0.8040 - val_loss: 0.4409 - val_accuracy: 0.7898
# Epoch 4/40
# 149/149 [==============================] - 21s 141ms/step - loss: 0.2883 - accuracy: 0.8763 - val_loss: 0.3662 - val_accuracy: 0.8598
# Epoch 5/40
# 149/149 [==============================] - 22s 147ms/step - loss: 0.2119 - accuracy: 0.9088 - val_loss: 0.3355 - val_accuracy: 0.8807
# Epoch 6/40
# 149/149 [==============================] - 21s 141ms/step - loss: 0.1725 - accuracy: 0.9292 - val_loss: 0.3272 - val_accuracy: 0.8845
# Epoch 7/40
# 149/149 [==============================] - 20s 137ms/step - loss: 0.1150 - accuracy: 0.9555 - val_loss: 0.3345 - val_accuracy: 0.8769
# Epoch 8/40
# 149/149 [==============================] - 21s 143ms/step - loss: 0.0890 - accuracy: 0.9673 - val_loss: 0.3669 - val_accuracy: 0.8826
# Epoch 9/40
# 149/149 [==============================] - 21s 139ms/step - loss: 0.1012 - accuracy: 0.9600 - val_loss: 0.4450 - val_accuracy: 0.8845
# Epoch 10/40
# 149/149 [==============================] - 22s 149ms/step - loss: 0.0928 - accuracy: 0.9678 - val_loss: 0.3906 - val_accuracy: 0.8845
# Epoch 11/40
# 149/149 [==============================] - 22s 145ms/step - loss: 0.0619 - accuracy: 0.9768 - val_loss: 0.3617 - val_accuracy: 0.9072
# Epoch 12/40
# 149/149 [==============================] - 21s 139ms/step - loss: 0.0556 - accuracy: 0.9796 - val_loss: 0.5578 - val_accuracy: 0.8902
# Epoch 13/40
# 149/149 [==============================] - 21s 138ms/step - loss: 0.0440 - accuracy: 0.9836 - val_loss: 0.3852 - val_accuracy: 0.9223
# Epoch 14/40
# 149/149 [==============================] - 21s 138ms/step - loss: 0.0375 - accuracy: 0.9882 - val_loss: 0.5592 - val_accuracy: 0.9091
# Epoch 15/40
# 149/149 [==============================] - 21s 143ms/step - loss: 0.0613 - accuracy: 0.9804 - val_loss: 0.5387 - val_accuracy: 0.8977
# Epoch 16/40
# 149/149 [==============================] - 21s 143ms/step - loss: 0.0787 - accuracy: 0.9743 - val_loss: 0.4183 - val_accuracy: 0.9053
# Epoch 17/40
# 149/149 [==============================] - 21s 138ms/step - loss: 0.0267 - accuracy: 0.9912 - val_loss: 0.5061 - val_accuracy: 0.8996
# Epoch 18/40
# 149/149 [==============================] - 21s 138ms/step - loss: 0.0363 - accuracy: 0.9882 - val_loss: 0.5100 - val_accuracy: 0.8958
# Epoch 19/40
# 149/149 [==============================] - 21s 139ms/step - loss: 0.0222 - accuracy: 0.9922 - val_loss: 0.8191 - val_accuracy: 0.8788
# Epoch 20/40
# 149/149 [==============================] - 21s 138ms/step - loss: 0.0622 - accuracy: 0.9804 - val_loss: 0.4835 - val_accuracy: 0.9053
# Epoch 21/40
# 149/149 [==============================] - 21s 144ms/step - loss: 0.0171 - accuracy: 0.9939 - val_loss: 0.5774 - val_accuracy: 0.9167
# Epoch 22/40
# 149/149 [==============================] - 21s 139ms/step - loss: 0.0144 - accuracy: 0.9958 - val_loss: 0.5783 - val_accuracy: 0.8977
# Epoch 23/40
# 149/149 [==============================] - 21s 144ms/step - loss: 0.0264 - accuracy: 0.9922 - val_loss: 0.5539 - val_accuracy: 0.8996
# Epoch 24/40
# 149/149 [==============================] - 21s 144ms/step - loss: 0.0177 - accuracy: 0.9939 - val_loss: 0.5232 - val_accuracy: 0.9072
# Epoch 25/40
# 149/149 [==============================] - 21s 144ms/step - loss: 0.0342 - accuracy: 0.9895 - val_loss: 0.6078 - val_accuracy: 0.8920
# Epoch 26/40
# 149/149 [==============================] - 21s 144ms/step - loss: 0.0344 - accuracy: 0.9899 - val_loss: 0.6322 - val_accuracy: 0.8939
# Epoch 27/40
# 149/149 [==============================] - 21s 139ms/step - loss: 0.0521 - accuracy: 0.9838 - val_loss: 0.8049 - val_accuracy: 0.8788
# Epoch 28/40
# 149/149 [==============================] - 21s 138ms/step - loss: 0.1022 - accuracy: 0.9701 - val_loss: 0.5522 - val_accuracy: 0.9015
# Epoch 29/40
# 149/149 [==============================] - 21s 143ms/step - loss: 0.0533 - accuracy: 0.9844 - val_loss: 0.4865 - val_accuracy: 0.9110
# Epoch 30/40
# 149/149 [==============================] - 21s 138ms/step - loss: 0.0092 - accuracy: 0.9977 - val_loss: 0.5867 - val_accuracy: 0.9205
# Epoch 31/40
# 149/149 [==============================] - 21s 138ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.5934 - val_accuracy: 0.9280
# Epoch 32/40
# 149/149 [==============================] - 21s 143ms/step - loss: 0.0073 - accuracy: 0.9981 - val_loss: 0.6648 - val_accuracy: 0.9072
# Epoch 33/40
# 149/149 [==============================] - 21s 138ms/step - loss: 0.0327 - accuracy: 0.9933 - val_loss: 0.6504 - val_accuracy: 0.8939
# Epoch 34/40
# 149/149 [==============================] - 21s 144ms/step - loss: 0.0603 - accuracy: 0.9823 - val_loss: 0.5190 - val_accuracy: 0.9072
# Epoch 35/40
# 149/149 [==============================] - 21s 144ms/step - loss: 0.0259 - accuracy: 0.9916 - val_loss: 0.6687 - val_accuracy: 0.8939
# Epoch 36/40
# 149/149 [==============================] - 21s 139ms/step - loss: 0.0060 - accuracy: 0.9979 - val_loss: 0.7047 - val_accuracy: 0.9091
# Epoch 37/40
# 149/149 [==============================] - 21s 144ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.6919 - val_accuracy: 0.9072
# Epoch 38/40
# 149/149 [==============================] - 21s 144ms/step - loss: 0.0023 - accuracy: 0.9996 - val_loss: 0.6841 - val_accuracy: 0.9072
# Epoch 39/40
# 149/149 [==============================] - 21s 138ms/step - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.7222 - val_accuracy: 0.9129
# Epoch 40/40
# 149/149 [==============================] - 21s 138ms/step - loss: 9.0427e-04 - accuracy: 0.9996 - val_loss: 0.7705 - val_accuracy: 0.9091

# %% [markdown]
# ### Evaluating and testing the model

# %%
# Evaluate the model
loss, accuracy = model.evaluate([X_test[:,0], X_test[:,1]], y_test, batch_size=batch_size)
print(f"Test accuracy: {accuracy}")
# Out:
# 19/19 [==============================] - 5s 281ms/step - loss: 0.7045 - accuracy: 0.9012
# Test accuracy: 0.9011924862861633

# %%
# Make predictions
y_pred = model.predict([X_test[:,0], X_test[:,1]], batch_size=batch_size)
y_pred = [1 if pred>0.5 else 0  for pred in y_pred]
# Out:
# 19/19 [==============================] - 2s 103ms/step

# %%
# Calculate F1 score
f1 = f1_score(y_test, y_pred, average='micro')
print(f"F1 score: {f1}")
# Out:
# F1 score: 0.9011925042589438

# %%
# Calculate F1 score
Report = classification_report(y_test, y_pred)
print(Report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.88      0.91       349
#            1       0.84      0.93      0.88       238
#
#     accuracy                           0.90       587
#    macro avg       0.90      0.91      0.90       587
# weighted avg       0.91      0.90      0.90       587

# %% [markdown]
# ### Confusion Matrix for test set

# %%
# Create confusion matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(5, 4))
sns.heatmap(cm, annot=True, cmap='Blues')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ### Loss and accuracy in training and validating the model

# %%
# Plot the loss values
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# Plot the accuracy values
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Saving the model

# %%
# Define the directory and filename
save_dir = 'Saved Models'
model_name = 'Face-Detection-Training-Pre-Trained-Model-3.h5'

# Save the model
model.save(os.path.join(save_dir, model_name))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
